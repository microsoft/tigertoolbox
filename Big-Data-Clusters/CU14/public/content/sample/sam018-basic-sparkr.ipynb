# %% [markdown]
# SAM018 - Basic Spark R Example
# ==============================
#
# Description
# -----------
#
# TODO
#
# ### Steps
#
# Explain steps here

# %%
x <- c(1, 2, 3)

# %%
spark

# %% [markdown]
# The following is from https://spark.apache.org/docs/latest/sparkr.html

# %%
head(mtcars, 6)

# %% [markdown]
# ### Create the SparkDataFrame

# %%
df <- as.DataFrame(mtcars)

# %%
head(df, 6)

# %% [markdown]
# Select column “mpg”

# %%
head(select(df, df$mpg), 6)

# %% [markdown]
# also pass in column name as strings

# %%
head(select(df, "qsec"), 6)

# %% [markdown]
# Filter the SparkDataFrame to only retain rows with weights less than
# 3.25 tonnes

# %%
head(filter(df, df$wt < 3.25), 6)

# %% [markdown]
# ### Grouping, aggregation
#
# Use the `n` operator to count the number of times each cylinder count
# appears

# %%
head(summarize(groupBy(df, df$cyl), count = n(df$cyl)))

# %% [markdown]
# Sort the output from the aggregation to get the most common numbers of
# gears

# %%
gear <- summarize(groupBy(df, df$gear), count = n(df$gear))
head(arrange(gear, desc(gear$count)))

# %% [markdown]
# OLAP cube operators cube:

# %%
head(agg(cube(df, "cyl", "disp", "gear"), avg(df$mpg)))

# %% [markdown]
# and rollup

# %%
head(agg(rollup(df, "cyl", "disp", "gear"), avg(df$mpg)))

# %% [markdown]
# assign a new value to a new column in the same SparkDataFrame

# %%
df$kpl <- df$mpg * 0.425
head(df, 6)

# %%
print "Notebook execution is complete."
